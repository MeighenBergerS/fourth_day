# %%
import numpy as np
import pandas as pd

# %%
grad=np.load('Parabola_5mm/run_2cm_npy/npy_values_grad/data_0.npy')

# %%
wind=np.load('Parabola_5mm/run_2cm_npy/npy_values_wind/data_0.npy')

# %%
grad,len(grad)
# Out:
# (array([[0.00131591],
#         [0.00124626],
#         [0.00115667],
#         ...,
#         [0.00115535],
#         [0.00124692],
#         [0.00131391]]),
#  106889)

# %%
wind,len(wind)
# Out:
# (array([[ 1.50028443e-02,  8.32770480e-07],
#         [ 1.56472060e-02,  1.31808696e-05],
#         [ 1.62473899e-02,  2.67973837e-05],
#         ...,
#         [ 1.62488848e-02, -1.58527918e-07],
#         [ 1.56488169e-02,  1.60616130e-07],
#         [ 1.50051501e-02,  8.41559574e-07]]),
#  106889)
